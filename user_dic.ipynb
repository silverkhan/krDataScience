# %% [markdown]
# <a href="https://colab.research.google.com/github/silverkhan/krDataScience/blob/master/user_dic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

nounDic_df = pd.DataFrame({
    "noun" : ['전문사모운용사',
              '금융투자분석사',
              '국제자산운용전문가',
              '재무위험관리사',
              '투자자산운용사',
              '재경관리사',
              '공인중개사',
              '데이터 아키텍처 전문가',
              '데이터분석준전문가',
              '데이터마케팅전문가',
              '농산물품질관리사',
              '식물보호산업기사',
              '신용분석사',
              '국제공인신용장전문가',
              '경영분석전문가',
              '유통관리사',
              'DT',
              '빅데이터',
              'HTML',
              'CSS',
              '오픈소스',
              '딥러닝',
              '디지털마케팅',
              '웹크롤링',
              '스마트뱅크',
              '플랫폼',
              '영업점',
              '회원조합',
              '연말정산',
              '백오피스',
              '금융권',
              '세무회계',
              '재무회계',
              '기업금융',
              '에센스',
              '직장인',
              '자존감',
              '농축협',
              '내부감사인',
              '내부감사',
              '기업분석',
              '채권회수',
              '보고서',
              '첫걸음',
              'M&A',
              '신회계제도',
              '사모펀드',
              '의사결정',
              '법정관리인',
              '상품개발',
              '품질관리',
              '현장지원단',
              '사업장',
              '하나로',
              '악성소비자',
              '회계기초',
              '대규모',
              '공시제도',
              '보험상품',
              '여신심사',
              '아웃바운드',
              '감사인',
              '출하',
              '1인',
              '금융시장',
              '문서작성',
              '역량강화',
              '보장법',
              '52시간',
              'RPA',
              'e-러닝',
              '스마트팜',
              '사내강사',
              '랜스위칭',
              '인사이트',
              '글쓰기',
              '스마트물류'
              ]})


nounDic_df.to_pickle("/content/nounDic_df.pkl")
# !ls
